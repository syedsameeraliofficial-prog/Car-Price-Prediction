# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
import seaborn as sns
from word2number import w2n

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_row', None)

# %%
df=pd.read_csv("Car_Price_Assignment.csv")
df
# Out:
#      car_ID  symboling                          CarName fueltype aspiration doornumber  \
# 0         1          3               alfa-romero giulia      gas        std        two
# 1         2          3              alfa-romero stelvio      gas        std        two
# 2         3          1         alfa-romero Quadrifoglio      gas        std        two
# 3         4          2                      audi 100 ls      gas        std       four
# 4         5          2                       audi 100ls      gas        std       four
# 5         6          2                         audi fox      gas        std        two
# 6         7          1                       audi 100ls      gas        std       four
# 7         8          1                        audi 5000      gas        std       four
# 8         9          1                        audi 4000      gas      turbo       four
# 9        10          0              audi 5000s (diesel)      gas      turbo        two
# ...

# %%
df.drop("car_ID" , axis=1 , inplace = True)

# %%
df.isnull().sum()
# Out:
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   CarName           205 non-null    object
#  2   fueltype          205 non-null    object
#  3   aspiration        205 non-null    object
#  4   doornumber        205 non-null    object
#  5   carbody           205 non-null    object
#  6   drivewheel        205 non-null    object
#  7   enginelocation    205 non-null    object
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    object
#  14  cylindernumber    205 non-null    object
#  15  enginesize        205 non-null    int64
# ...

# %%
df
# Out:
#      symboling                          CarName fueltype aspiration doornumber      carbody  \
# 0            3               alfa-romero giulia      gas        std        two  convertible
# 1            3              alfa-romero stelvio      gas        std        two  convertible
# 2            1         alfa-romero Quadrifoglio      gas        std        two    hatchback
# 3            2                      audi 100 ls      gas        std       four        sedan
# 4            2                       audi 100ls      gas        std       four        sedan
# 5            2                         audi fox      gas        std        two        sedan
# 6            1                       audi 100ls      gas        std       four        sedan
# 7            1                        audi 5000      gas        std       four        wagon
# 8            1                        audi 4000      gas      turbo       four        sedan
# ...

# %%
df.doornumber=df.doornumber.apply(w2n.word_to_num)
df.cylindernumber=df.cylindernumber.apply(w2n.word_to_num)

df
# Out:
#      symboling                          CarName fueltype aspiration  doornumber      carbody  \
# 0            3               alfa-romero giulia      gas        std           2  convertible
# 1            3              alfa-romero stelvio      gas        std           2  convertible
# 2            1         alfa-romero Quadrifoglio      gas        std           2    hatchback
# 3            2                      audi 100 ls      gas        std           4        sedan
# 4            2                       audi 100ls      gas        std           4        sedan
# 5            2                         audi fox      gas        std           2        sedan
# 6            1                       audi 100ls      gas        std           4        sedan
# 7            1                        audi 5000      gas        std           4        wagon
# 8            1                        audi 4000      gas      turbo           4        sedan
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
reg=linear_model.LinearRegression()
reg
# Out:
# LinearRegression()

# %%
price=df.price

# %%
df.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel',
#        'enginelocation', 'wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
#        'enginetype', 'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
drop=df.drop(['CarName' , 'symboling' ,'enginelocation' , 'wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight','enginetype', 'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
       'compressionratio' , 'price', ] , axis=1)

# %%
drop
# Out:
#      fueltype aspiration  doornumber      carbody drivewheel  horsepower  peakrpm  citympg  \
# 0           0        std           2  convertible        rwd         111     5000       21
# 1           0        std           2  convertible        rwd         111     5000       21
# 2           0        std           2    hatchback        rwd         154     5000       19
# 3           0        std           4        sedan        fwd         102     5500       24
# 4           0        std           4        sedan        4wd         115     5500       18
# 5           0        std           2        sedan        fwd         110     5500       19
# 6           0        std           4        sedan        fwd         110     5500       19
# 7           0        std           4        wagon        fwd         110     5500       19
# 8           0      turbo           4        sedan        fwd         140     5500       17
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   CarName           205 non-null    object
#  2   fueltype          205 non-null    int64
#  3   aspiration        205 non-null    object
#  4   doornumber        205 non-null    int64
#  5   carbody           205 non-null    object
#  6   drivewheel        205 non-null    object
#  7   enginelocation    205 non-null    object
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    object
#  14  cylindernumber    205 non-null    int64
#  15  enginesize        205 non-null    int64
# ...

# %%
df.fueltype.nunique()
# Out:
# 2

# %%
df.fueltype.unique()
# Out:
# array([0, 1])

# %%
df.aspiration.unique()
# Out:
# array(['std', 'turbo'], dtype=object)

# %%
df.drivewheel.unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df.carbody.unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
drop['fueltype'] = drop['fueltype'].replace({'gas': 0, 'diesel': 1})
drop['aspiration'] = drop['aspiration'].replace({'std': 0, 'turbo': 1})
drop['drivewheel'] = drop['drivewheel'].replace({'rwd': 0, 'fwd': 1,'4wd': 2})
drop['carbody'] = drop['carbody'].replace({'convertible': 0, 'hatchback': 1,'sedan': 2, 'wagon': 3, 'hardtop': 4})
# Out:
# C:\Users\hp 840\AppData\Local\Temp\ipykernel_16220\1879644359.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   drop['aspiration'] = drop['aspiration'].replace({'std': 0, 'turbo': 1})
# C:\Users\hp 840\AppData\Local\Temp\ipykernel_16220\1879644359.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   drop['drivewheel'] = drop['drivewheel'].replace({'rwd': 0, 'fwd': 1,'4wd': 2})
# ...

# %%
drop
# Out:
#      fueltype  aspiration  doornumber  carbody  drivewheel  horsepower  peakrpm  citympg  \
# 0           0           0           2        0           0         111     5000       21
# 1           0           0           2        0           0         111     5000       21
# 2           0           0           2        1           0         154     5000       19
# 3           0           0           4        2           1         102     5500       24
# 4           0           0           4        2           2         115     5500       18
# 5           0           0           2        2           1         110     5500       19
# 6           0           0           4        2           1         110     5500       19
# 7           0           0           4        3           1         110     5500       19
# 8           0           1           4        2           1         140     5500       17
# ...

# %%
reg.fit(drop,price)
# Out:
# LinearRegression()

# %%
reg.predict([[1,1,4,3,2,120,5500,21,29]])
# Out:
# C:\Users\hp 840\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([16555.74431945])
